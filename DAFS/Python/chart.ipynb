# %%
from IPython.display import Image, display

# Display the generated flowcharts
for file_path in files:
    print(f"Displaying: {file_path}")
    display(Image(filename=file_path))
# Out:
# Displaying: ./python_flowcharts/flowchart1_core_basics.png
# Displaying: ./python_flowcharts/flowchart2_exceptions_modules.png
# Displaying: ./python_flowcharts/flowchart3_data_analytics.png
# Displaying: ./python_flowcharts/flowchart4_file_advanced.png
# Displaying: ./python_flowcharts/flowchart5_coding_problems.png

# %%
from IPython.display import Image, display

# Display the combined OOP flowchart
print(f"Displaying: {png_path}")
display(Image(filename=png_path))
# Out:
# Displaying: ./python_oop_flowcharts/python_oop_combined.png
