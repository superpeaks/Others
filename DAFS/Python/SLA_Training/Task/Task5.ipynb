# %%
# The sequence starts with 0 and 1, and each subsequent number is the sum of the two preceding numbers
a,b=0,1
num = int(input("Enter a num:"))
for i in range(num):
    print(a)
    c=a+b
    a=b
    b=c
# Out:
# Enter a num: 5
# 0
# 1
# 1
# 2
# 3

# %%
# A palindrome is a word, phrase, number, or sequence that reads the same forward and backward.

ip = str(input("Enter a string"))
rev =''

for i in ip:
    rev=i+rev
print('reverse string',rev)
if ip==rev:
    print('palindrome')
else:
    print("not palindrome")
# Out:
# Enter a string level
# reverse string level
# palindrome

# %%
s=0

for i in range(10):
    num=int(input(f"Num{i+1}"))
    if num%2==0:
        s+=num
print(s)
# Out:
# Num1 1
# Num2 2
# Num3 3
# Num4 4
# Num5 5
# Num6 6
# Num7 7
# Num8 8
# Num9 9
# Num10 10
# 30

# %%
la=[]
ld=[]
for i in range(5):
    val=str(input(f"Val {i+1}"))
    if val.isalpha():
        la.append(val)
    elif val.isdigit():
        ld.append(val)
        
print(la)
print(ld)
# Out:
# Val 1 54654
# Val 2 eglkhkge
# Val 3 lhkrgn
# Val 4 lkhfdg545
# Val 5 65468
# ['eglkhkge', 'lhkrgn']
# ['54654', '65468']

# %%
e=o=0
for i in range(100,500+1):
    if i%2==0:
        e+=i
    else:
        o+=1
print("Sum of Even",e)
print("Count of odd",o)
# Out:
# Sum of Even 60300
# Count of odd 200

# %%
1 is 1
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_162838/1728060598.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   1 is 1
# True

# %%
a = 'ram'
b = 'ram'

a is b
# Out:
# True
