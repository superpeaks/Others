# %%
import pandas as pd

# %%
df = pd.read_excel("/media/rajesh/Rajesh/Python/SLA_Training/Sales_Analysis_Report.xlsx")
df.sample()
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 7735  SO - 0006290 2019-11-08 2019-11-23                   24  Distributor
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# 7735           NZD         FLR025            85               7
#
#       Order Quantity  Unit Price  Total Unit Cost  Total Revenue
# 7735               7       804.0           385.92         5628.0

# %%
df1 = df[df["Channel"] == 'Distributor']

# %%
df2 = df[df["Channel"] == 'Export']

# %%
df1
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 10    SO - 0005609 2017-01-02 2017-01-10                   22  Distributor
# 12    SO - 0006534 2017-01-02 2017-01-11                   46  Distributor
# 19    SO - 0003775 2017-01-03 2017-01-15                    5  Distributor
# 21    SO - 0004386 2017-01-03 2017-01-08                   39  Distributor
# ...            ...        ...        ...                  ...          ...
# 7976  SO - 0006605 2019-12-10 2019-12-24                   22  Distributor
# 7981   SO - 000142 2019-12-12 2019-12-28                   24  Distributor
# 7983  SO - 0001900 2019-12-12 2019-12-28                   25  Distributor
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df2
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index Channel  \
# 4     SO - 0005614 2017-01-01 2017-01-07                   27  Export
# 20    SO - 0004247 2017-01-03 2017-01-14                   14  Export
# 28    SO - 0007587 2017-01-03 2017-01-06                    5  Export
# 35    SO - 0005147 2017-01-04 2017-01-18                   48  Export
# 41    SO - 0003588 2017-01-05 2017-01-15                   26  Export
# ...            ...        ...        ...                  ...     ...
# 7942  SO - 0002504 2019-12-06 2019-12-20                   22  Export
# 7946  SO - 0005873 2019-12-07 2019-12-20                   30  Export
# 7966  SO - 0004381 2019-12-09 2019-12-15                   20  Export
# 7971  SO - 0007920 2019-12-09 2019-12-23                   18  Export
# 7975  SO - 0005668 2019-12-10 2019-12-17                   45  Export
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df2.merge(right=df1,how='outer',on='OrderNumber')
# Out:
#        OrderNumber OrderDate_x Ship Date_x  Customer Name Index_x Channel_x  \
# 0     SO - 0005614  2017-01-01  2017-01-07                   27.0    Export
# 1     SO - 0004247  2017-01-03  2017-01-14                   14.0    Export
# 2     SO - 0007587  2017-01-03  2017-01-06                    5.0    Export
# 3     SO - 0005147  2017-01-04  2017-01-18                   48.0    Export
# 4     SO - 0003588  2017-01-05  2017-01-15                   26.0    Export
# ...            ...         ...         ...                    ...       ...
# 3700  SO - 0006605         NaT         NaT                    NaN       NaN
# 3701   SO - 000142         NaT         NaT                    NaN       NaN
# 3702  SO - 0001900         NaT         NaT                    NaN       NaN
# 3703  SO - 0005477         NaT         NaT                    NaN       NaN
# 3704  SO - 0007126         NaT         NaT                    NaN       NaN
#
# ...

# %%
df.groupby()

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales_data.csv')

# %%
df.set_index('OrderID', inplace=True)

# %%
df.isnull().sum()
# Out:
# OrderDate          0
# Region             0
# Product            0
# Quantity           0
# UnitPrice          0
# CustomerSegment    0
# Discount           0
# ShippingCost       0
# DeliveryDate       2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 1001 to 1025
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderDate        25 non-null     object
#  1   Region           25 non-null     object
#  2   Product          25 non-null     object
#  3   Quantity         25 non-null     int64
#  4   UnitPrice        25 non-null     float64
#  5   CustomerSegment  25 non-null     object
#  6   Discount         25 non-null     float64
#  7   ShippingCost     25 non-null     float64
#  8   DeliveryDate     23 non-null     object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.0+ KB

# %%
df.sample(3)
# Out:
#           OrderDate   Region   Product  Quantity  UnitPrice CustomerSegment  \
# OrderID
# 1010     2023-01-14     West    Webcam         4       35.0        Consumer
# 1016     2023-01-20  Central    Laptop         1     1200.0        Consumer
# 1023     2023-01-27     West  Keyboard         2       75.0       Corporate
#
#          Discount  ShippingCost DeliveryDate
# OrderID
# 1010         0.05           7.5   2023-01-18
# 1016         0.05          25.0   2023-01-24
# 1023         0.10          10.0   2023-01-31

# %%
df.shape
# Out:
# (25, 9)

# %%
df.columns
# Out:
# Index(['OrderDate', 'Region', 'Product', 'Quantity', 'UnitPrice',
#        'CustomerSegment', 'Discount', 'ShippingCost', 'DeliveryDate'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Quantity   UnitPrice   Discount  ShippingCost
# count  25.000000    25.00000  25.000000     25.000000
# mean    2.160000   327.10000   0.054000     14.100000
# std     1.280625   457.01208   0.047697     10.677078
# min     1.000000    25.50000   0.000000      5.000000
# 25%     1.000000    35.00000   0.000000      7.500000
# 50%     2.000000    75.00000   0.050000     10.000000
# 75%     3.000000   300.00000   0.100000     15.000000
# max     5.000000  1200.00000   0.150000     50.000000

# %%
df1 = pd.to_datetime('DeliveryDate',dayfirst=True,)

# %%
df
# Out:
#           OrderDate   Region   Product  Quantity  UnitPrice CustomerSegment  \
# OrderID
# 1001     2023-01-05     East    Laptop         1     1200.0        Consumer
# 1002     2023-01-06     West     Mouse         3       25.5       Corporate
# 1003     2023-01-07  Central  Keyboard         2       75.0     Home Office
# 1004     2023-01-08     East   Monitor         1      300.0        Consumer
# 1005     2023-01-09    South    Webcam         5       35.0       Corporate
# 1006     2023-01-10     West    Laptop         1     1200.0     Home Office
# 1007     2023-01-11  Central     Mouse         2       25.5        Consumer
# 1008     2023-01-12     East  Keyboard         3       75.0       Corporate
# 1009     2023-01-13    South   Monitor         1      300.0     Home Office
# 1010     2023-01-14     West    Webcam         4       35.0        Consumer
# 1011     2023-01-15     East    Laptop         2     1200.0       Corporate
# ...

# %%
import pandas as pd

# %%
df = pd.read_sql('show databases;', con = 'mysql+pymysql://root:password@localhost')

# %%
df
# Out:
#              Database
# 0                ecom
# 1  information_schema
# 2               mysql
# 3  performance_schema
# 4                 sys

# %%
# Out:
#              Database
# 0                ecom
# 1  information_schema
# 2               mysql
# 3  performance_schema
# 4                 sys

# %%
import pandas as pd

# %%
df = pd.read_excel("/media/rajesh/Rajesh/Python/SLA_Training/Sales_Analysis_Report.xlsx",index_col='OrderNumber',dtype={'OrderNumber':str})
df.sample(3)
# Out:
#               OrderDate  Ship Date  Customer Name Index    Channel  \
# OrderNumber
# SO - 0001030 2018-06-02 2018-06-09                   47     Export
# SO - 0002001 2019-03-28 2019-04-08                   40  Wholesale
# SO - 0004794 2019-07-14 2019-07-20                   10  Wholesale
#
#              Currency Code Warehouse Code  Region Index  Product  Index  \
# OrderNumber
# SO - 0001030           USD         GUT930            74               9
# SO - 0002001           NZD         NXH382            76               2
# SO - 0004794           NZD         NXH382            93               1
#
#               Order Quantity  Unit Price  Total Unit Cost  Total Revenue
# OrderNumber
# SO - 0001030              12      2003.3          921.518        24039.6
# SO - 0002001               5       254.6          145.122         1273.0
# SO - 0004794               9      3892.7         2841.671        35034.3

# %%
df.set_index('OrderNumber', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6092/992074648.py in ?()
# ----> 1 df.set_index('OrderNumber', inplace=True)
#
# ~/venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#    5873             frame = self
#
# KeyError: "None of ['OrderNumber'] are in the columns"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7991 entries, SO - 000225 to SO - 0007668
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderDate            7991 non-null   datetime64[ns]
#  1   Ship Date            7991 non-null   datetime64[ns]
#  2   Customer Name Index  7991 non-null   int64
#  3   Channel              7991 non-null   object
#  4   Currency Code        7991 non-null   object
#  5   Warehouse Code       7991 non-null   object
#  6   Region Index         7991 non-null   int64
#  7   Product  Index       7991 non-null   int64
#  8   Order Quantity       7991 non-null   int64
#  9   Unit Price           7991 non-null   float64
#  10  Total Unit Cost      7991 non-null   float64
#  11  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(3)
# memory usage: 811.6+ KB

# %%
df.describe()
# Out:
#                            OrderDate                      Ship Date  \
# count                           7991                           7991
# mean   2018-06-22 01:36:56.944061952  2018-07-02 12:04:35.710173952
# min              2017-01-01 00:00:00            2017-01-05 00:00:00
# 25%              2017-09-23 00:00:00            2017-10-03 00:00:00
# 50%              2018-06-20 00:00:00            2018-07-01 00:00:00
# 75%              2019-03-20 00:00:00            2019-04-01 00:00:00
# max              2019-12-12 00:00:00            2019-12-28 00:00:00
# std                              NaN                            NaN
#
#        Customer Name Index  Region Index  Product  Index  Order Quantity  \
# count          7991.000000   7991.000000     7991.000000     7991.000000
# mean             25.457014     50.454261        6.340383        8.456889
# min               1.000000      1.000000        1.000000        5.000000
# ...

# %%
df.shape
# Out:
# (7991, 12)

# %%
df.columns
# Out:
# Index(['OrderDate', 'Ship Date', 'Customer Name Index', 'Channel',
#        'Currency Code', 'Warehouse Code', 'Region Index', 'Product  Index',
#        'Order Quantity', 'Unit Price', 'Total Unit Cost', 'Total Revenue'],
#       dtype='object')

# %%
df.index
# Out:
# Index(['SO - 000225', 'SO - 0003378', 'SO - 0003901', 'SO - 0005126',
#        'SO - 0005614', 'SO - 0005781', 'SO - 0002911', 'SO - 0003527',
#        'SO - 0004792', 'SO - 0005414',
#        ...
#        'SO - 000142', 'SO - 0001226', 'SO - 0001900', 'SO - 0003334',
#        'SO - 0003615', 'SO - 0005237', 'SO - 0005477', 'SO - 0006936',
#        'SO - 0007126', 'SO - 0007668'],
#       dtype='object', name='OrderNumber', length=7991)

# %%
df.drop(columns=['Warehouse Code', 'Region Index'])
# Out:
#               OrderDate  Ship Date  Customer Name Index      Channel  \
# OrderNumber
# SO - 000225  2017-01-01 2017-01-13                   28    Wholesale
# SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...                 ...        ...                  ...          ...
# SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#              Currency Code  Product  Index  Order Quantity  Unit Price  \
# OrderNumber
# ...

# %%
df.rename(columns={'Total Unit Cost':'Unit_cost_on_proquirement', 'Total Revenue':'Sales'},inplace=True)

# %%
df.sample(2)
# Out:
#               OrderDate  Ship Date  Customer Name Index    Channel  \
# OrderNumber
# SO - 0002128 2017-04-16 2017-04-26                   43     Export
# SO - 0003984 2017-05-15 2017-05-20                   23  Wholesale
#
#              Currency Code Warehouse Code  Region Index  Product  Index  \
# OrderNumber
# SO - 0002128           USD         AXW291            37               7
# SO - 0003984           USD         AXW291            73               6
#
#               Order Quantity  Unit Price  Unit_cost_on_proquirement    Sales
# OrderNumber
# SO - 0002128               8      6545.9                   3076.573  52367.2
# SO - 0003984              11      1996.6                   1697.110  21962.6

# %%
temp = df[(df['Sales']>50000) & (df['Channel']== 'Export') &(df['Currency Code'] != 'USD') & (df['Warehouse Code']!='AXW291')].copy(deep=True)

# %%
temp.describe()
# Out:
#                  OrderDate            Ship Date  Customer Name Index  \
# count                   27                   27            27.000000
# mean   2019-03-20 04:26:40  2019-03-30 07:06:40            23.518519
# min    2018-06-30 00:00:00  2018-07-11 00:00:00             4.000000
# 25%    2019-01-02 12:00:00  2019-01-07 12:00:00            14.000000
# 50%    2019-03-14 00:00:00  2019-03-20 00:00:00            21.000000
# 75%    2019-07-25 12:00:00  2019-07-31 12:00:00            31.500000
# max    2019-10-19 00:00:00  2019-10-29 00:00:00            50.000000
# std                    NaN                  NaN            13.857434
#
#        Region Index  Product  Index  Order Quantity   Unit Price  \
# count     27.000000       27.000000       27.000000    27.000000
# mean      56.555556        6.851852       10.666667  5900.962963
# min        6.000000        1.000000        8.000000  5092.000000
# 25%       29.500000        4.500000        9.500000  5440.400000
# ...

# %%
temp.sample(3)
# Out:
#               OrderDate  Ship Date  Customer Name Index Channel Currency Code  \
# OrderNumber
# SO - 0002463 2019-10-04 2019-10-13                   21  Export           GBP
# SO - 0002139 2019-05-16 2019-05-25                   34  Export           NZD
# SO - 0002190 2019-10-04 2019-10-13                   19  Export           NZD
#
#              Warehouse Code  Region Index  Product  Index  Order Quantity  \
# OrderNumber
# SO - 0002463         FLR025            15              11              11
# SO - 0002139         NXH382            14              11              10
# SO - 0002190         FLR025            29               2              12
#
#               Unit Price  Unit_cost_on_proquirement    Sales
# OrderNumber
# SO - 0002463      6378.4                   3252.984  70162.4
# SO - 0002139      6177.4                   2779.830  61774.0
# SO - 0002190      6083.6                   2555.112  73003.2

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, SO - 0003778 to SO - 0004871
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   OrderDate                  27 non-null     datetime64[ns]
#  1   Ship Date                  27 non-null     datetime64[ns]
#  2   Customer Name Index        27 non-null     int64
#  3   Channel                    27 non-null     object
#  4   Currency Code              27 non-null     object
#  5   Warehouse Code             27 non-null     object
#  6   Region Index               27 non-null     int64
#  7   Product  Index             27 non-null     int64
#  8   Order Quantity             27 non-null     int64
#  9   Unit Price                 27 non-null     float64
#  10  Unit_cost_on_proquirement  27 non-null     float64
#  11  Sales                      27 non-null     float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(3)
# ...

# %%
temp.rename(columns={'Sales':'sales'},inplace=True)

# %%
pd.to_datetime(temp['OrderDate'],format='%d-%b-%Y').head()
# Out:
# OrderNumber
# SO - 0003778   2018-06-30
# SO - 0005770   2018-07-04
# SO - 000622    2018-08-14
# SO - 0002855   2018-09-16
# SO - 000584    2018-09-20
# Name: OrderDate, dtype: datetime64[ns]

# %%
temp['oeder_year'] = temp['OrderDate'].dt.year

# %%
temp['order_month'] = temp['OrderDate'].dt.month

# %%
temp['order_month_names'] = temp['OrderDate'].dt.month_name()

# %%
temp['order_day_names'] = temp['OrderDate'].dt.day_name()

# %%
temp['order_day'] = temp['OrderDate'].dt.day

# %%
temp.sample(3)
# Out:
#               OrderDate  Ship Date  Customer Name Index Channel Currency Code  \
# OrderNumber
# SO - 0005770 2018-07-04 2018-07-15                   14  Export           EUR
# SO - 0007353 2019-01-25 2019-02-05                   19  Export           AUD
# SO - 0004871 2019-10-19 2019-10-29                    9  Export           NZD
#
#              Warehouse Code  Region Index  Product  Index  Order Quantity  \
# OrderNumber
# SO - 0005770         GUT930            12              13              12
# SO - 0007353         NXH382            90               7              11
# SO - 0004871         FLR025            11               2               9
#
#               Unit Price  Unit_cost_on_proquirement    sales  oeder_year  \
# OrderNumber
# SO - 0005770      6378.4                   3508.120  76540.8        2018
# SO - 0007353      5092.0                   4226.360  56012.0        2019
# SO - 0004871      5681.6                   2897.616  51134.4        2019
#
# ...

# %%
temp['Delivered_duration'] = temp['Ship Date'] - temp['OrderDate']

# %%
temp['profit'] = (temp['sales'])-(temp['Unit_cost_on_proquirement']*temp['Order Quantity'])

# %%
temp.sample(3)
# Out:
#               OrderDate  Ship Date  Customer Name Index Channel Currency Code  \
# OrderNumber
# SO - 0003933 2019-04-25 2019-05-01                   21  Export           NZD
# SO - 000677  2018-12-03 2018-12-15                   45  Export           GBP
# SO - 000584  2018-09-20 2018-09-29                   39  Export           GBP
#
#              Warehouse Code  Region Index  Product  Index  Order Quantity  \
# OrderNumber
# SO - 0003933         NXH382            67               1               9
# SO - 000677          GUT930             6               5              11
# SO - 000584          GUT930            42               7              11
#
#               Unit Price  Unit_cost_on_proquirement    sales  oeder_year  \
# OrderNumber
# SO - 0003933      6277.9                   2636.718  56501.1        2019
# SO - 000677       5353.3                   4496.772  58886.3        2018
# SO - 000584       5835.7                   3968.276  64192.7        2018
#
# ...

# %%
temp['Warehouse Code'].value_counts()
# Out:
# Warehouse Code
# NXH382    15
# GUT930     8
# FLR025     4
# Name: count, dtype: int64

# %%
temp['Delivered_duration'].unique()
# Out:
# <TimedeltaArray>
# ['11 days', '15 days', '10 days',  '9 days', '12 days',  '4 days',  '6 days',
#  '17 days',  '8 days',  '7 days',  '5 days']
# Length: 11, dtype: timedelta64[ns]

# %%
temp['Delivered_duration'].nunique()
# Out:
# 11

# %%
temp['Delivered_duration'].value_counts()
# Out:
# Delivered_duration
# 11 days    4
# 9 days     4
# 6 days     4
# 15 days    3
# 10 days    3
# 12 days    3
# 17 days    2
# 4 days     1
# 8 days     1
# 7 days     1
# 5 days     1
# Name: count, dtype: int64

# %%
temp
# Out:
#               OrderDate  Ship Date  Customer Name Index Channel Currency Code  \
# OrderNumber
# SO - 0003778 2018-06-30 2018-07-11                   14  Export           EUR
# SO - 0005770 2018-07-04 2018-07-15                   14  Export           EUR
# SO - 000622  2018-08-14 2018-08-29                    4  Export           NZD
# SO - 0002855 2018-09-16 2018-09-26                   18  Export           AUD
# SO - 000584  2018-09-20 2018-09-29                   39  Export           GBP
# SO - 000677  2018-12-03 2018-12-15                   45  Export           GBP
# SO - 0003336 2018-12-29 2019-01-02                   49  Export           NZD
# SO - 0003777 2019-01-07 2019-01-13                    5  Export           AUD
# SO - 0007353 2019-01-25 2019-02-05                   19  Export           AUD
# SO - 0007679 2019-01-26 2019-02-12                   50  Export           AUD
# SO - 000819  2019-02-05 2019-02-22                   22  Export           NZD
# ...

# %%
temp.groupby(['oeder_year', 'order_day_names'])['profit'].aggregate(['mean','min','max','sum','count'])
# Out:
#                                     mean        min        max         sum  \
# oeder_year order_day_names
# 2018       Monday            9421.808000   9421.808   9421.808    9421.808
#            Saturday         29326.704000  28415.772  30237.636   58653.408
#            Sunday           23865.534000  23865.534  23865.534   23865.534
#            Thursday         20541.664000  20541.664  20541.664   20541.664
#            Tuesday          26837.118000  26837.118  26837.118   26837.118
#            Wednesday        34443.360000  34443.360  34443.360   34443.360
# 2019       Friday           25948.939200   9522.040  42341.856  129744.696
#            Monday           27352.080000  27352.080  27352.080   27352.080
#            Saturday         22321.636250   9760.091  33859.254   89286.545
#            Thursday         26644.445143  12636.200  39527.856  186511.116
#            Tuesday          23745.135000  21386.400  26103.870   47490.270
# ...

# %%
temp1 = temp.groupby(['oeder_year', 'order_day_names'])['profit'].aggregate(['mean','min','max','sum','count']).copy(deep=True)

# %%
temp1
# Out:
#                                     mean        min        max         sum  \
# oeder_year order_day_names
# 2018       Monday            9421.808000   9421.808   9421.808    9421.808
#            Saturday         29326.704000  28415.772  30237.636   58653.408
#            Sunday           23865.534000  23865.534  23865.534   23865.534
#            Thursday         20541.664000  20541.664  20541.664   20541.664
#            Tuesday          26837.118000  26837.118  26837.118   26837.118
#            Wednesday        34443.360000  34443.360  34443.360   34443.360
# 2019       Friday           25948.939200   9522.040  42341.856  129744.696
#            Monday           27352.080000  27352.080  27352.080   27352.080
#            Saturday         22321.636250   9760.091  33859.254   89286.545
#            Thursday         26644.445143  12636.200  39527.856  186511.116
#            Tuesday          23745.135000  21386.400  26103.870   47490.270
# ...

# %%
temp1.to_excel('fi.xlsx',merge_cells=False)

# %%
pwd
# Out:
# '/media/rajesh/Rajesh/Python/SLA_Training/mine'

# %%
temp1.reset_index(inplace=True)

# %%
temp1
# Out:
#     oeder_year order_day_names          mean        min        max  \
# 0         2018          Monday   9421.808000   9421.808   9421.808
# 1         2018        Saturday  29326.704000  28415.772  30237.636
# 2         2018          Sunday  23865.534000  23865.534  23865.534
# 3         2018        Thursday  20541.664000  20541.664  20541.664
# 4         2018         Tuesday  26837.118000  26837.118  26837.118
# 5         2018       Wednesday  34443.360000  34443.360  34443.360
# 6         2019          Friday  25948.939200   9522.040  42341.856
# 7         2019          Monday  27352.080000  27352.080  27352.080
# 8         2019        Saturday  22321.636250   9760.091  33859.254
# 9         2019        Thursday  26644.445143  12636.200  39527.856
# 10        2019         Tuesday  23745.135000  21386.400  26103.870
# 11        2019       Wednesday  23348.160000  23348.160  23348.160
#
#            sum  count
# 0     9421.808      1
# 1    58653.408      2
# 2    23865.534      1
# ...

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df.loc[2:8,'Currency Code']
# Out:
# 2    NZD
# 3    USD
# 4    NZD
# 5    GBP
# 6    EUR
# 7    USD
# 8    NZD
# Name: Currency Code, dtype: object

# %%
df.sort_values(by='Currency Code')
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 3560  SO - 0003038 2018-04-21 2018-05-03                   27    Wholesale
# 5946  SO - 0005625 2019-03-14 2019-03-18                   10  Distributor
# 1031   SO - 000288 2017-05-21 2017-06-01                   19  Distributor
# 3331  SO - 0002476 2018-03-19 2018-04-06                    8    Wholesale
# 1028  SO - 0006062 2017-05-20 2017-06-05                   34       Export
# ...            ...        ...        ...                  ...          ...
# 5754  SO - 0006779 2019-02-13 2019-02-24                   26    Wholesale
# 5755  SO - 0006999 2019-02-13 2019-02-21                   32  Distributor
# 5756   SO - 000736 2019-02-14 2019-02-24                    7    Wholesale
# 5758  SO - 0002553 2019-02-14 2019-02-28                   39       Export
# 3995  SO - 0004214 2018-06-20 2018-07-03                    3  Distributor
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df.drop(index=1)
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# 5     SO - 0005781 2017-01-01 2017-01-15                   44    Wholesale
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
pd.concat(
    
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.concat(
#       2
#       3 )
#
# TypeError: concat() missing 1 required positional argument: 'objs'

# %%
import pandas as pd
import mysql

# %%
df = pd.read_sql("show databases;", con='pysql+mysql://root@password:localhost')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_sql("show databases;", con='pysql+mysql://root@password:localhost')
#
# File ~/venv/lib/python3.12/site-packages/pandas/io/sql.py:652, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     649     dtype_backend = "numpy"  # type: ignore[assignment]
#     650 assert dtype_backend is not lib.no_default
# --> 652 with pandasSQL_builder(con) as pandas_sql:
#     653     if isinstance(pandas_sql, SQLiteDatabase):
#     654         return pandas_sql.read_query(
#     655             sql,
#     656             index_col=index_col,
#    (...)    662             dtype=dtype,
#     663         )
#
# File ~/venv/lib/python3.12/site-packages/pandas/io/sql.py:851, in pandasSQL_builder(con, schema, need_transaction)
# ...

# %%
df = pd.read_excel("/media/rajesh/Rajesh/Python/SLA_Training/Sales_Analysis_Report.xlsx")
df.sample()
# Out:
#       OrderNumber  OrderDate  Ship Date  Customer Name Index    Channel  \
# 410  SO - 0001617 2017-02-28 2017-03-13                    4  Wholesale
#
#     Currency Code Warehouse Code  Region Index  Product  Index  \
# 410           NZD         AXW291           100               3
#
#      Order Quantity  Unit Price  Total Unit Cost  Total Revenue
# 410               8       247.9            99.16         1983.2

# %%
df.loc[1:20,'Total Revenue'].plot(kind='line')
# Out:
# <Axes: >
