# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %% [markdown]
# ### File informations

# %%
df.shape #size
# Out:
# (246091, 7)

# %%
df.info() #Basic Informations and Data Types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
df.describe() #Statistical Information
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.423610e+05
# mean     2005.643018  1.200282e+04  5.825034e+05
# std         4.952164  5.052340e+04  1.706581e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  8.800000e+01
# 50%      2006.000000  5.820000e+02  7.290000e+02
# 75%      2010.000000  4.392000e+03  7.023000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
df.isnull().sum() #Count of Null
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
df.isna().sum() #Count of Error values
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
df.iloc[16] #selecting particular row using index number
# Out:
# State_Name       Andaman and Nicobar Islands
# District_Name                       NICOBARS
# Crop_Year                               2001
# Season                           Whole Year
# Crop                               Sugarcane
# Area                                     1.0
# Production                               1.0
# Name: 16, dtype: object

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %% [markdown]
# ### Selecting 1 to 20 rows

# %%
df[:20]
# Out:
#                      State_Name District_Name  Crop_Year       Season  \
# 0   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 10  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 11  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 12  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# ...

# %% [markdown]
# ### Saving File

# %%
df1 = df[:20]
df1.to_csv('Temp.csv',index=False)
df1.to_excel('Temp.xlsx',sheet_name='Temp',index=False)
df1
# Out:
#                      State_Name District_Name  Crop_Year       Season  \
# 0   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 10  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 11  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 12  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# ...

# %%
df.iloc[[1,2,5,8,9,10]] #selecting particular row using index number
# Out:
#                      State_Name District_Name  Crop_Year       Season  \
# 1   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 5   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 10  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
#
#                    Crop     Area  Production
# 1   Other Kharif pulses      2.0         1.0
# 2                  Rice    102.0       321.0
# 5              Coconut   18168.0  65100000.0
# 8          Sweet potato      5.0        15.0
# 9               Tapioca     40.0       169.0
# 10             Arecanut   1254.0      2061.0

# %%
df[['Season','Crop','State_Name']] #selecting particular column using name
# Out:
#              Season                 Crop                   State_Name
# 0       Kharif                  Arecanut  Andaman and Nicobar Islands
# 1       Kharif       Other Kharif pulses  Andaman and Nicobar Islands
# 2       Kharif                      Rice  Andaman and Nicobar Islands
# 3       Whole Year                Banana  Andaman and Nicobar Islands
# 4       Whole Year             Cashewnut  Andaman and Nicobar Islands
# ...             ...                  ...                          ...
# 246086  Summer                      Rice                  West Bengal
# 246087  Summer                   Sesamum                  West Bengal
# 246088  Whole Year             Sugarcane                  West Bengal
# 246089  Winter                      Rice                  West Bengal
# 246090  Winter                   Sesamum                  West Bengal
#
# [246091 rows x 3 columns]

# %%
arr = np.array(df['Crop_Year']) #Converting pandas to 1D numpy array
arr
# Out:
# array([2000, 2000, 2000, ..., 2014, 2014, 2014], dtype=int64)

# %% [markdown]
# ### Get Data from WEB(html)

# %%
df2 = pd.read_html('https://www.moneycontrol.com/india/indexfutures/nifty/9?classic=true') 

print(len(df2))

print(df2)

print(df2[0])
# Out:
# 17
# [              0         1
# 0    Open Price  19611.20
# 1    High Price  19701.90
# 2     Low Price  19512.25
# 3   Prev. Close  19611.25
# 4    Spot Price  19632.55
# 5  Open Int PCR      1.18
# 6   Prev OI PCR      0.99
# 7     Bid Price  19693.00
# 8       Bid Qty       650
# 9    Rollover %    14.39%,                          0            1
# 0            Average Price     19599.14
# 1  No. of Contracts Traded    111392.00
# 2  Turnover (Rs. in lakhs)   1091593.70
# 3               Market Lot        50.00
# 4            Open Interest  11195200.00
# 5            Open Int. Chg     98000.00
# 6          Open Int. Chg %         0.88
# 7              Offer Price     19693.35
# 8                Offer Qty       200.00,   Unnamed: 0_level_0 CONTRACT           VALUE
#   Unnamed: 0_level_1  Futures Options Futures Options
# 0             Stocks        0       0     0.0     0.0
# 1              Index        0       0     0.0     0.0
# ...

# %%
for item in df2:
    print(item)
    print("\n\n")
# Out:
#               0         1
# 0    Open Price  19611.20
# 1    High Price  19701.90
# 2     Low Price  19512.25
# 3   Prev. Close  19611.25
# 4    Spot Price  19632.55
# 5  Open Int PCR      1.18
# 6   Prev OI PCR      0.99
# 7     Bid Price  19693.00
# 8       Bid Qty       650
# 9    Rollover %    14.39%
#
#
#
#                          0            1
# 0            Average Price     19599.14
# 1  No. of Contracts Traded    111392.00
# 2  Turnover (Rs. in lakhs)   1091593.70
# 3               Market Lot        50.00
# 4            Open Interest  11195200.00
# 5            Open Int. Chg     98000.00
# 6          Open Int. Chg %         0.88
# 7              Offer Price     19693.35
# 8                Offer Qty       200.00
#
#
#
#   Unnamed: 0_level_0 CONTRACT           VALUE
#   Unnamed: 0_level_1  Futures Options Futures Options
# 0             Stocks        0       0     0.0     0.0
# 1              Index        0       0     0.0     0.0
# ...

# %% [markdown]
# ### Pivot tables

# %%
df.head(2)
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0

# %% [markdown]
# #### Basic Pivot

# %%
df_pivot = df.pivot_table(values=['Area','Production'],index=['Season','State_Name'],columns='Crop_Year')
df_pivot
# Out:
#                                                   Area                 \
# Crop_Year                                         1997           1998
# Season      State_Name
# Autumn      Andaman and Nicobar Islands            NaN            NaN
#             Assam                         26406.869565   25868.652174
#             Bihar                         18021.967742            NaN
#             Jharkhand                              NaN            NaN
#             Kerala                                 NaN    9247.461538
# ...                                                ...            ...
# Winter      Manipur                                NaN    1708.400000
#             Meghalaya                              NaN            NaN
#             Odisha                        17554.337838   12736.959732
#             Puducherry                             NaN            NaN
#             West Bengal                  237240.444444  223812.222222
#
# ...

# %% [markdown]
# ### Total Column(Marigin), fill nan value

# %%
df_pivot1 = df.pivot_table(values=['Area','Production'],index=['Season','State_Name'],columns='Crop_Year',fill_value=0 , margins=True, margins_name='Total')
df_pivot1.to_excel('pvot1.xlsx',sheet_name='pivot')
df_pivot1
# Out:
#                                                   Area                 \
# Crop_Year                                         1997           1998
# Season      State_Name
# Autumn      Andaman and Nicobar Islands       0.000000       0.000000
#             Assam                         26406.869565   25868.652174
#             Bihar                         18021.967742       0.000000
#             Jharkhand                         0.000000       0.000000
#             Kerala                            0.000000    9247.461538
# ...                                                ...            ...
# Winter      Meghalaya                         0.000000       0.000000
#             Odisha                        17554.337838   12736.959732
#             Puducherry                        0.000000       0.000000
#             West Bengal                  237240.444444  223812.222222
# Total                                     26038.324081   14795.911383
#
# ...

# %% [markdown]
# ### No null drop

# %%
df_pivot3 = df.pivot_table(values=['Area','Production'],index=['Season','State_Name'],columns='Crop_Year',dropna = False,fill_value=0 , margins=True, margins_name='Total')
df_pivot3.to_excel('pivot2.xlsx',sheet_name='pivot')
df_pivot3
# Out:
#                                                   Area                 \
# Crop_Year                                         1997           1998
# Season      State_Name
# Autumn      Andaman and Nicobar Islands       0.000000       0.000000
#             Andhra Pradesh                    0.000000       0.000000
#             Arunachal Pradesh                 0.000000       0.000000
#             Assam                         26406.869565   25868.652174
#             Bihar                         18021.967742       0.000000
# ...                                                ...            ...
# Winter      Tripura                           0.000000       0.000000
#             Uttar Pradesh                     0.000000       0.000000
#             Uttarakhand                       0.000000       0.000000
#             West Bengal                  237240.444444  223812.222222
# Total                                     26038.324081   14479.153906
#
# ...

# %% [markdown]
# ### multiple aggregation column

# %%
df_pivot2 = df.pivot_table(values=['Area','Production'],index=['Season','State_Name'],
                          aggfunc={'Area':[np.mean,np.count_nonzero],'Production':[np.mean,max,min,np.sum,np.std]},margins=False)
df_pivot2.to_excel('pivot.xlsx',sheet_name="pivot")
df_pivot2
# Out:
#                                                  Area                 \
#                                         count_nonzero           mean
# Season      State_Name
# Autumn      Andaman and Nicobar Islands             6    1424.038333
#             Assam                                 562   14477.777580
#             Bihar                                 860   18553.359302
#             Jharkhand                             293    7207.743993
#             Kerala                                221    6980.258416
# ...                                               ...            ...
# Winter      Manipur                                50    1708.400000
#             Meghalaya                              92    7484.826087
#             Odisha                               3808   15301.687500
#             Puducherry                              6    4217.666667
#             West Bengal                           458  158127.733624
#
# ...

# %% [markdown]
# ### slice

# %%
df_piv = df.pivot_table(values=['Area','Production'],index=['Season','State_Name'])
df_piv
# Out:
#                                                   Area     Production
# Season      State_Name
# Autumn      Andaman and Nicobar Islands    1424.038333    4208.158333
#             Assam                         14477.777580   14644.476868
#             Bihar                         18553.359302   27500.507567
#             Jharkhand                      7207.743993    6565.487509
#             Kerala                         6980.258416   15576.693801
# ...                                                ...            ...
# Winter      Manipur                        1708.400000    4163.800000
#             Meghalaya                      7484.826087   15235.804348
#             Odisha                        15301.687500   27016.432044
#             Puducherry                     4217.666667    8928.000000
#             West Bengal                  158127.733624  400743.810044
#
# [132 rows x 2 columns]

# %%
df_piv["Area"]
# Out:
# Season       State_Name
# Autumn       Andaman and Nicobar Islands      1424.038333
#              Assam                           14477.777580
#              Bihar                           18553.359302
#              Jharkhand                        7207.743993
#              Kerala                           6980.258416
#                                                 ...
# Winter       Manipur                          1708.400000
#              Meghalaya                        7484.826087
#              Odisha                          15301.687500
#              Puducherry                       4217.666667
#              West Bengal                    158127.733624
# Name: Area, Length: 132, dtype: float64

# %%
df_piv["Area"].iloc[1]
# Out:
# 14477.777580071175

# %% [markdown]
# #### Error

# %%
df_piv["Area"].set_index("Season")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10184\2000224139.py in ?()
# ----> 1 df_piv["Area"].set_index("Season")
#
# c:\Users\Rajes\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %% [markdown]
# ### Numpy operations in Pandas

# %%
df.shape
# Out:
# (246091, 7)

# %%
a,b = df.shape
df["ID"] = np.arange(3000001,3000000+a+1) #Adding column
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production       ID
# ...

# %% [markdown]
# ### Index changing and Index calling

# %%
df.set_index('ID',inplace=True) #Inplace Permanatly save changes
df
# Out:
#                           State_Name District_Name  Crop_Year       Season  \
# ID
# 3000001  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3000002  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3000003  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3000004  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 3000005  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                              ...           ...        ...          ...
# 3246087                  West Bengal       PURULIA       2014  Summer
# 3246088                  West Bengal       PURULIA       2014  Summer
# 3246089                  West Bengal       PURULIA       2014  Whole Year
# 3246090                  West Bengal       PURULIA       2014  Winter
# 3246091                  West Bengal       PURULIA       2014  Winter
#
#                         Crop      Area  Production
# ID
# ...

# %%
df.loc[[3000001,3000004,3000200]] # Row selection using Index name
# Out:
#                           State_Name   District_Name  Crop_Year       Season  \
# ID
# 3000001  Andaman and Nicobar Islands        NICOBARS       2000  Kharif
# 3000004  Andaman and Nicobar Islands        NICOBARS       2000  Whole Year
# 3000200  Andaman and Nicobar Islands  SOUTH ANDAMANS       2010  Rabi
#
#              Crop    Area  Production
# ID
# 3000001  Arecanut  1254.0     2000.00
# 3000004    Banana   176.0      641.00
# 3000200      Urad    34.0       15.05

# %% [markdown]
# ### ADD/Remove column

# %%
a,b = df.shape
df['Temp'] = np.arange(1,a+1)
df
# Out:
#                           State_Name District_Name  Crop_Year       Season  \
# ID
# 3000001  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3000002  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3000003  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3000004  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 3000005  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                              ...           ...        ...          ...
# 3246087                  West Bengal       PURULIA       2014  Summer
# 3246088                  West Bengal       PURULIA       2014  Summer
# 3246089                  West Bengal       PURULIA       2014  Whole Year
# 3246090                  West Bengal       PURULIA       2014  Winter
# 3246091                  West Bengal       PURULIA       2014  Winter
#
#                         Crop      Area  Production    Temp
# ID
# ...

# %%
df.drop('Temp',axis=1,inplace=True)
df.head(2)
# Out:
#                           State_Name District_Name Crop_Year       Season  \
# ID
# 3000001  Andaman and Nicobar Islands      NICOBARS      2000  Kharif
# 3000002  Andaman and Nicobar Islands      NICOBARS      2000  Kharif
#
#                         Crop    Area Production
# ID
# 3000001             Arecanut  1254.0     2000.0
# 3000002  Other Kharif pulses     2.0        1.0

# %% [markdown]
# ### ADD/Remove Row

# %%
df.loc[246091] = [3246092,'Temp','Temp1','temp2','Temp','Temp1','temp2','temp65']
df.tail(2)
# Out:
#           State_Name District_Name Crop_Year       Season     Crop   Area  \
# ID
# 3246091  West Bengal       PURULIA      2014  Winter       Sesamum  175.0
# 246091       3246092          Temp     Temp1        temp2     Temp  Temp1
#
#         Production    Temp
# ID
# 3246091       88.0  246091
# 246091       temp2  temp65

# %%
df.drop(246091,inplace=True)
df.tail(2)
# Out:
#           State_Name District_Name Crop_Year       Season     Crop      Area  \
# ID
# 3246090  West Bengal       PURULIA      2014  Winter          Rice  279151.0
# 3246091  West Bengal       PURULIA      2014  Winter       Sesamum     175.0
#
#         Production
# ID
# 3246090   597899.0
# 3246091       88.0

# %% [markdown]
# ### Sort_values/filter / Group by

# %%
df.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.423610e+05
# mean     2005.643018  1.200282e+04  5.825034e+05
# std         4.952164  5.052340e+04  1.706581e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  8.800000e+01
# 50%      2006.000000  5.820000e+02  7.290000e+02
# 75%      2010.000000  4.392000e+03  7.023000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
print(df[df['Crop']=='Rice'])
print(df[df['Crop']=='Rice'].count())
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 12      Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 18      Andaman and Nicobar Islands      NICOBARS       2002  Kharif
# 27      Andaman and Nicobar Islands      NICOBARS       2003  Kharif
# 36      Andaman and Nicobar Islands      NICOBARS       2004  Kharif
# ...                             ...           ...        ...          ...
# 246049                  West Bengal       PURULIA       2013  Summer
# 246052                  West Bengal       PURULIA       2013  Winter
# 246058                  West Bengal       PURULIA       2014  Autumn
# 246086                  West Bengal       PURULIA       2014  Summer
# 246089                  West Bengal       PURULIA       2014  Winter
#
#         Crop       Area  Production
# 2       Rice     102.00      321.00
# 12      Rice      83.00      300.00
# ...

# %%
df[df['Crop']=='Rice'].sort_values(by='Area',ascending=False)
# Out:
#             State_Name District_Name  Crop_Year       Season  Crop      Area  \
# 148599          Odisha       BARGARH       2012  Summer       Rice  687000.0
# 147754          Odisha      BALANGIR       2012  Summer       Rice  623000.0
# 55060     Chhattisgarh        RAIPUR       2010  Kharif       Rice  545965.0
# 153477          Odisha     KALAHANDI       2012  Summer       Rice  542000.0
# 54934     Chhattisgarh        RAIPUR       2007  Kharif       Rice  539878.0
# ...                ...           ...        ...          ...   ...       ...
# 168858       Rajasthan         DAUSA       2001  Kharif       Rice       1.0
# 167514       Rajasthan       BIKANER       2007  Kharif       Rice       1.0
# 28395            Bihar         BANKA       2000  Kharif       Rice       1.0
# 160608      Puducherry          MAHE       1998  Rabi         Rice       1.0
# 114907  Madhya Pradesh      MANDSAUR       2007  Kharif       Rice       1.0
#
#         Production
# 148599    265000.0
# ...

# %%
df[((df['Area']<100) | (df['Production']<100)) & ((df['Crop_Year']==2005) & (df['District_Name']=='THENI'))].sort_values(by='Area',ascending=False)
# Out:
#         State_Name District_Name  Crop_Year       Season               Crop  \
# 186627  Tamil Nadu         THENI       2005  Kharif                    Urad
# 186635  Tamil Nadu         THENI       2005  Whole Year        Dry chillies
# 186620  Tamil Nadu         THENI       2005  Kharif       Moong(Green Gram)
# 186625  Tamil Nadu         THENI       2005  Kharif           Small millets
# 186626  Tamil Nadu         THENI       2005  Kharif               Sunflower
# 186614  Tamil Nadu         THENI       2005  Kharif             Castor seed
# 186622  Tamil Nadu         THENI       2005  Kharif                    Ragi
# 186630  Tamil Nadu         THENI       2005  Whole Year        Black pepper
# 186628  Tamil Nadu         THENI       2005  Whole Year            Arecanut
# 186640  Tamil Nadu         THENI       2005  Whole Year             Tobacco
# 186634  Tamil Nadu         THENI       2005  Whole Year           Coriander
# ...

# %%
df.groupby(df['Season'],group_keys=True).max()
# Out:
#               State_Name District_Name  Crop_Year            Crop       Area  \
# Season
# Autumn       West Bengal         YANAM       2015            Urad   212760.0
# Kharif       West Bengal     ZUNHEBOTO       2015  other oilseeds  1020181.0
# Rabi         West Bengal     ZUNHEBOTO       2015  other oilseeds  8580100.0
# Summer       West Bengal      YAVATMAL       2015           Wheat   687000.0
# Whole Year   West Bengal     ZUNHEBOTO       2014  other oilseeds  4307200.0
# Winter       West Bengal         YANAM       2015           Wheat   513019.0
#
#                Production
# Season
# Autumn       5.426920e+05
# Kharif       1.775796e+07
# Rabi         7.556300e+06
# Summer       8.822890e+05
# Whole Year   1.250800e+09
# Winter       1.841788e+06

# %%
df.groupby(df['Season']).max()
# Out:
#               State_Name District_Name  Crop_Year            Crop       Area  \
# Season
# Autumn       West Bengal         YANAM       2015            Urad   212760.0
# Kharif       West Bengal     ZUNHEBOTO       2015  other oilseeds  1020181.0
# Rabi         West Bengal     ZUNHEBOTO       2015  other oilseeds  8580100.0
# Summer       West Bengal      YAVATMAL       2015           Wheat   687000.0
# Whole Year   West Bengal     ZUNHEBOTO       2014  other oilseeds  4307200.0
# Winter       West Bengal         YANAM       2015           Wheat   513019.0
#
#                Production
# Season
# Autumn       5.426920e+05
# Kharif       1.775796e+07
# Rabi         7.556300e+06
# Summer       8.822890e+05
# Whole Year   1.250800e+09
# Winter       1.841788e+06

# %%
df.groupby(df['Season']).sum()
# Out:
#                                                     State_Name  \
# Season
# Autumn       Andaman and Nicobar IslandsAndaman and Nicobar...
# Kharif       Andaman and Nicobar IslandsAndaman and Nicobar...
# Rabi         Andaman and Nicobar IslandsAndaman and Nicobar...
# Summer       AssamAssamAssamAssamAssamAssamAssamAssamAssamA...
# Whole Year   Andaman and Nicobar IslandsAndaman and Nicobar...
# Winter       AssamAssamAssamAssamAssamAssamAssamAssamAssamA...
#
#                                                  District_Name  Crop_Year  \
# Season
# Autumn       NICOBARSNICOBARSNORTH AND MIDDLE ANDAMANNORTH ...    9931847
# Kharif       NICOBARSNICOBARSNICOBARSNICOBARSNICOBARSNICOBA...  192433963
# Rabi         NICOBARSNICOBARSNICOBARSNICOBARSNICOBARSNICOBA...  134375352
# Summer       BAKSABAKSABAKSABAKSABAKSABAKSABAKSABAKSABAKSAB...   29783876
# Whole Year   NICOBARSNICOBARSNICOBARSNICOBARSNICOBARSNICOBA...  114886975
# ...

# %%
df.groupby(df['Season']).sum(numeric_only=True)
# Out:
#              Crop_Year          Area    Production
# Season
# Autumn         9931847  4.807113e+07  6.441377e+07
# Kharif       192433963  1.404845e+09  4.029970e+09
# Rabi         134375352  9.479874e+08  2.051688e+09
# Summer        29783876  7.598406e+07  1.706579e+08
# Whole Year   114886975  2.573005e+08  1.344248e+11
# Winter        12158683  2.195979e+08  4.345498e+08

# %%
grp = df.groupby(df['District_Name'])
grp.first()
# Out:
#                         State_Name  Crop_Year       Season       Crop  \
# District_Name
# 24 PARAGANAS NORTH     West Bengal       1997  Autumn            Rice
# 24 PARAGANAS SOUTH     West Bengal       1997  Autumn            Rice
# ADILABAD                Telangana        1997  Kharif       Arhar/Tur
# AGAR MALWA          Madhya Pradesh       2013  Kharif       Arhar/Tur
# AGRA                 Uttar Pradesh       1997  Kharif       Arhar/Tur
# ...                            ...        ...          ...        ...
# YADGIR                   Karnataka       2010  Kharif       Arhar/Tur
# YAMUNANAGAR                Haryana       1997  Kharif           Bajra
# YANAM                   Puducherry       1998  Kharif       Coriander
# YAVATMAL               Maharashtra       1997  Kharif       Arhar/Tur
# ZUNHEBOTO                 Nagaland       1997  Kharif           Bajra
#
#                         Area  Production
# District_Name
# 24 PARAGANAS NORTH   15017.0     33840.0
# ...

# %%
grp.get_group("AGRA") #All AGRA group list
# Out:
#            State_Name District_Name  Crop_Year       Season  \
# 198276  Uttar Pradesh          AGRA       1997  Kharif
# 198277  Uttar Pradesh          AGRA       1997  Kharif
# 198278  Uttar Pradesh          AGRA       1997  Kharif
# 198279  Uttar Pradesh          AGRA       1997  Kharif
# 198280  Uttar Pradesh          AGRA       1997  Kharif
# ...               ...           ...        ...          ...
# 198739  Uttar Pradesh          AGRA       2014  Rabi
# 198740  Uttar Pradesh          AGRA       2014  Rabi
# 198741  Uttar Pradesh          AGRA       2014  Summer
# 198742  Uttar Pradesh          AGRA       2014  Summer
# 198743  Uttar Pradesh          AGRA       2014  Summer
#
#                      Crop      Area  Production
# 198276          Arhar/Tur    6538.0      9664.0
# 198277              Bajra   99898.0    147994.0
# 198278          Groundnut      27.0        22.0
# 198279              Jowar     725.0       406.0
# 198280              Maize     138.0       316.0
# ...

# %%
grp1 = df.groupby(['Season','Crop'])
grp1.first()
# Out:
#                                       State_Name           District_Name  \
# Season      Crop
# Autumn      Arhar/Tur                     Odisha                  ANUGUL
#             Banana                       Manipur                 CHANDEL
#             Cotton(lint)                 Manipur           CHURACHANDPUR
#             Dry chillies                 Manipur               BISHNUPUR
#             Dry ginger                   Manipur                 CHANDEL
# ...                                          ...                     ...
# Winter      Sunflower     Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI
#             Sweet potato                 Manipur                SENAPATI
#             Turmeric                     Manipur           CHURACHANDPUR
#             Urad                          Odisha                  ANUGUL
#             Wheat         Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI
#
#                           Crop_Year    Area  Production
# ...

# %% [markdown]
# ### Concatenating

# %%
df.head(2)
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0

# %%
df_con1 = pd.DataFrame({'A':['A0', 'A1', 'A2'], 'B':['B0','B1','B2'],'C':['C0','C1','C2'],'key1':['K0','K1','K2'],'key0':['K6','K7','K8']},index=[0,1,2])
df_con2 = pd.DataFrame({'A':['A3','A4','A5'], 'B':['B3','B4','B5'], 'C':['C3','C4','C5'],'key2':['K3','K4','K5'],'key0':['K6','K7','K8']}, index = [3,4,5])

print(df_con1)
print(df_con2)
# Out:
#     A   B   C key1 key0
# 0  A0  B0  C0   K0   K6
# 1  A1  B1  C1   K1   K7
# 2  A2  B2  C2   K2   K8
#     A   B   C key2 key0
# 3  A3  B3  C3   K3   K6
# 4  A4  B4  C4   K4   K7
# 5  A5  B5  C5   K5   K8

# %%
pd.concat([df_con1,df_con2],axis=0) #pd.concat([df_con1,df_con2])
# Out:
#     A   B   C key1 key0 key2
# 0  A0  B0  C0   K0   K6  NaN
# 1  A1  B1  C1   K1   K7  NaN
# 2  A2  B2  C2   K2   K8  NaN
# 3  A3  B3  C3  NaN   K6   K3
# 4  A4  B4  C4  NaN   K7   K4
# 5  A5  B5  C5  NaN   K8   K5

# %%
pd.concat([df_con1,df_con2],axis=1)
# Out:
#      A    B    C key1 key0    A    B    C key2 key0
# 0   A0   B0   C0   K0   K6  NaN  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   K1   K7  NaN  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   K2   K8  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN   A3   B3   C3   K3   K6
# 4  NaN  NaN  NaN  NaN  NaN   A4   B4   C4   K4   K7
# 5  NaN  NaN  NaN  NaN  NaN   A5   B5   C5   K5   K8

# %%
pd.concat([df_con1,df_con2],join='inner',keys='key0')
# Out:
#       A   B   C key0
# k 0  A0  B0  C0   K6
#   1  A1  B1  C1   K7
#   2  A2  B2  C2   K8
# e 3  A3  B3  C3   K6
#   4  A4  B4  C4   K7
#   5  A5  B5  C5   K8

# %%
pd.concat([df_con1,df_con2],join='inner',keys=['key0','key1'])
# Out:
#          A   B   C key0
# key0 0  A0  B0  C0   K6
#      1  A1  B1  C1   K7
#      2  A2  B2  C2   K8
# key1 3  A3  B3  C3   K6
#      4  A4  B4  C4   K7
#      5  A5  B5  C5   K8

# %%
pd.concat([df_con1,df_con2],join='inner',keys=['key0','key1','key2'])
# Out:
#          A   B   C key0
# key0 0  A0  B0  C0   K6
#      1  A1  B1  C1   K7
#      2  A2  B2  C2   K8
# key1 3  A3  B3  C3   K6
#      4  A4  B4  C4   K7
#      5  A5  B5  C5   K8

# %%
pd.concat([df_con1,df_con2],join='outer',keys=['key0','key2'])
# Out:
#          A   B   C key1 key0 key2
# key0 0  A0  B0  C0   K0   K6  NaN
#      1  A1  B1  C1   K1   K7  NaN
#      2  A2  B2  C2   K2   K8  NaN
# key2 3  A3  B3  C3  NaN   K6   K3
#      4  A4  B4  C4  NaN   K7   K4
#      5  A5  B5  C5  NaN   K8   K5

# %%
pd.concat([df_con1,df_con2],join='outer',keys=['key0','key2'],axis = 1)
# Out:
#   key0                     key2
#      A    B    C key1 key0    A    B    C key2 key0
# 0   A0   B0   C0   K0   K6  NaN  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   K1   K7  NaN  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   K2   K8  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN   A3   B3   C3   K3   K6
# 4  NaN  NaN  NaN  NaN  NaN   A4   B4   C4   K4   K7
# 5  NaN  NaN  NaN  NaN  NaN   A5   B5   C5   K5   K8

# %% [markdown]
# ### Merging

# %%
pd.merge(left=df_con1,right=df_con2,how='inner',on=['key0'])
# Out:
#   A_x B_x C_x key1 key0 A_y B_y C_y key2
# 0  A0  B0  C0   K0   K6  A3  B3  C3   K3
# 1  A1  B1  C1   K1   K7  A4  B4  C4   K4
# 2  A2  B2  C2   K2   K8  A5  B5  C5   K5

# %%
pd.merge(left=df_con1,right=df_con2,how='outer',on=['key0'])
# Out:
#   A_x B_x C_x key1 key0 A_y B_y C_y key2
# 0  A0  B0  C0   K0   K6  A3  B3  C3   K3
# 1  A1  B1  C1   K1   K7  A4  B4  C4   K4
# 2  A2  B2  C2   K2   K8  A5  B5  C5   K5

# %%
pd.merge(left=df_con1,right=df_con2,how='left',on=['key0'])
# Out:
#   A_x B_x C_x key1 key0 A_y B_y C_y key2
# 0  A0  B0  C0   K0   K6  A3  B3  C3   K3
# 1  A1  B1  C1   K1   K7  A4  B4  C4   K4
# 2  A2  B2  C2   K2   K8  A5  B5  C5   K5

# %%
pd.merge(left=df_con1,right=df_con2,how='right',on=['key0'])
# Out:
#   A_x B_x C_x key1 key0 A_y B_y C_y key2
# 0  A0  B0  C0   K0   K6  A3  B3  C3   K3
# 1  A1  B1  C1   K1   K7  A4  B4  C4   K4
# 2  A2  B2  C2   K2   K8  A5  B5  C5   K5

# %% [markdown]
# # END
