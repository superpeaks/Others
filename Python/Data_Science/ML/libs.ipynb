# %%
# !pip install -U scikit-learn numpy scipy joblib threadpoolctl matplotlib pandas seaborn plotly openpyxl

# %%
import platform

# %%
platform.system()
# Out:
# 'Windows'

# %%
platform.system()
# Out:
# 'Windows'
